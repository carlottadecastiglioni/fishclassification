# %%
from sklearn.utils import shuffle
import pandas as pd
import numpy as np

fish = pd.read_excel('fish_classification_dataset.xlsx')

missing_rate = 0.1  # 10% missing values

for col in fish.columns[:-1]:
    if pd.api.types.is_numeric_dtype(fish[col]):
        missing_indices = np.random.choice(fish.index, size=int(missing_rate * len(fish)), replace=False)
        fish.loc[missing_indices, col] = np.nan

# %%
fish
# Out:
#       Length  Weight  Water Type     Habitat       Diet Coloration Fish Type
# 0        NaN   188.0   Saltwater       River   Omnivore        Red      Tuna
# 1      290.0     NaN  Freshwater        Reef  Carnivore    Spotted   Catfish
# 2      126.0   430.0  Freshwater  Open Ocean  Carnivore       Blue   Catfish
# 3       91.0   308.0   Saltwater       River  Herbivore      Green      Tuna
# 4      208.0   138.0   Saltwater        Lake   Omnivore    Spotted      Tuna
# ...      ...     ...         ...         ...        ...        ...       ...
# 9995    74.0   332.0  Freshwater        Lake   Omnivore    Striped     Trout
# 9996   228.0   326.0  Freshwater        Lake  Carnivore     Silver      Bass
# 9997     NaN   252.0   Saltwater  Open Ocean   Omnivore     Yellow      Tuna
# 9998    87.0   394.0   Saltwater  Open Ocean  Carnivore     Silver      Tuna
# 9999   152.0   322.0   Saltwater     Coastal   Omnivore    Spotted      Tuna
#
# [10000 rows x 7 columns]

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=d1c78d89-6ec7-469d-838f-00c7cf4991d6' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
